# %%
from utils import real_data
from viz import im_convert
import matplotlib.pyplot as plt
import numpy as np

# %%
train_loader, test_loader, class_names = real_data["MRI"](n_test=10, subsample=True)

# %%
X_test, y_test = next(iter(test_loader))

# %%
plt.imshow(im_convert(X_test[6]))

# %%
plt.imshow(im_convert(X_test[6][:,45:85,35:75]))

# %%
plt.imshow(im_convert(X_test[7]))

# %%
plt.imshow(im_convert(X_test[7][:,10:50,40:80]))

# %%
X_test[6:8]
# Out:
# tensor([[[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.0837, -2.0837, -2.0837,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.0665, -2.0665, -2.0665,  ..., -2.1179, -2.1179, -2.1179],
#           ...,
#           [-2.0837, -2.0837, -2.0837,  ..., -2.0494, -2.0665, -2.0665],
#           [-2.1008, -2.1008, -2.1008,  ..., -2.0837, -2.0837, -2.0837],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#          [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0007, -2.0007, -2.0007,  ..., -2.0357, -2.0357, -2.0357],
#           [-1.9832, -1.9832, -1.9832,  ..., -2.0357, -2.0357, -2.0357],
#           ...,
#           [-2.0007, -2.0007, -2.0007,  ..., -1.9657, -1.9832, -1.9832],
#           [-2.0182, -2.0182, -2.0182,  ..., -2.0007, -2.0007, -2.0007],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
# ...

# %%
def crop(self, size, box):
    mask = np.ones(size, dtype=bool)
    output = []
    for i, data in enumerate(array):
        output.append(data[:, box[i][0]:box[i][1], box[i][2]:box[i][3]])
    return np.stack(output)

# %%
np.prod((1,2,3))
# Out:
# 6

# %%
X_flat = X_test.reshape(X_test.shape[0], -1)

# %%
X_test.shape.pop(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6de6bd348b08> in <module>
# ----> 1 X_test.shape.pop(0)
#
# AttributeError: 'torch.Size' object has no attribute 'pop'
